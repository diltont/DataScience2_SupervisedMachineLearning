# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import learning_curve
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import plotly.express as px
from plotly.offline import plot
from sklearn.preprocessing import StandardScaler
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
init_notebook_mode(connected=True)

import scipy
import statsmodels.formula.api as smf
import statsmodels.api as sm
from catboost import CatBoostClassifier

from sklearn import model_selection,  feature_selection, ensemble, linear_model, metrics, decomposition

import shap
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Background
# The data used for final assignment for supervised learning is Parkisons data. The goal of this assignment is to preidct whether a person has Parkinson or not based on vocal features from phonation data.The data set consists of 195 obervations from  31 subjects (48 vowel phonations recorded from the subjects in the normal group and 147 vowel phonations recorded from the patients with Parkinson's disease in the pathological group).
# Since the target varaible consists of two classes , supervised machine learning classification models are implemented.

# %% [markdown]
# ## 1.Data loading and inspection
# This part shows reading the data into dataframe and some analysis on dataframe such as df. describe, df.info etc.

# %%
path='C:\Dilton G\Hanze_University\S2_Q4  Hanze\Dat science 3 Prediction'

park=pd.read_csv(path+'\parkinsons.data')
park.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
park.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
park.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %% [markdown]
# The data looks clean as there is no missing values and no unwanted data types. We have 195 observations(samples) and 22 features(predictors). The target variable(output variable) is the status column which tells whether the person has parkinson disease or not.

# %% [markdown]
# ## 2.Exploratory data analysis
# This part shows visualizations of the data such as distribution, correlations , count plot etc.

# %%
# changing status 0 and 1 to yes and no for better understanding
park['Parkinson']=np.where(park['status']==1,'yes','no')

# Target dataframe.
y=park['status']
# Feature dataframe slicing.
x=park.loc[:,~park.columns.isin(['status', 'name','Parkinson'])]
park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
#  24  Parkinson         195 non-null    object
# dtypes: float64(22), int64(1), object(2)
# memory usage: 38.2+ KB

# %%
# Count plot showing number of people with parkinson
plt.figure(figsize = (5, 5))
ax = sns.countplot(x=park['Parkinson'], palette = 'PuBu')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 0, ha = "right")
plt.suptitle("Count of Parkison")
plt.show()

# %%
# Correlation matrix to find correlation.
corr_matrix = x.corr().abs()
# Only upper matrix is plotted. Upper half and lower half are same
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
plt.figure(figsize = (20, 8))
sns.heatmap(upper, cmap = 'PuBu', annot = True,)
plt.show()

# %% [markdown]
# Some features are highly correalted and can result multicollinearity and eventually in overfitting. These featurees are removed in the next section .i.e feature engineering

# %% [markdown]
# ## 3. Feature Engineering
# This part focuses two parts:1) Feature selection and 2) Feature scaling.
# Feature selection involves dimensionality reduction which reduces the number of dimensions(features). I have applied an ensmeble method in this assignment to select most relevant features.
# Initially, all correlated features are found using correlation matrix. Second lasso regularization with anova is done to find the feature importance. Finally I used these two methods to drop the least important features.
# The threshold for correlation is set as .95.

# %%
def corr_drop(upper):
    """Function to implement lasso regularization.
    classifiers: List of classifieers
    Input:
    Upper half of the correlation matrix
    
    Ouputs:
    drop1: List of features which are highly correlated
    """

    # Find index of feature columns with correlation greater than 0.95
    high_corr_var=np.where(upper>0.9)
    # Getting column and row names(features)
    high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y])  for x,y in zip(*high_corr_var) if x!=y and x<y]
    # Unstacking the list of tuples into a single list of column names.
    drop1=list(sum(high_corr_var, ()))
    return drop1

#Getting list of correlated features
drop1=corr_drop(upper)
drop1
# Out:
# ['MDVP:Jitter(%)',
#  'MDVP:Jitter(Abs)',
#  'MDVP:Jitter(%)',
#  'MDVP:RAP',
#  'MDVP:Jitter(%)',
#  'MDVP:PPQ',
#  'MDVP:Jitter(%)',
#  'Jitter:DDP',
#  'MDVP:Jitter(%)',
#  'NHR',
#  'MDVP:Jitter(Abs)',
#  'MDVP:RAP',
#  'MDVP:Jitter(Abs)',
#  'Jitter:DDP',
#  'MDVP:RAP',
#  'MDVP:PPQ',
#  'MDVP:RAP',
#  'Jitter:DDP',
#  'MDVP:RAP',
#  'NHR',
#  'MDVP:PPQ',
#  'Jitter:DDP',
#  'Jitter:DDP',
#  'NHR',
#  'MDVP:Shimmer',
#  'MDVP:Shimmer(dB)',
#  'MDVP:Shimmer',
#  'Shimmer:APQ3',
#  'MDVP:Shimmer',
#  'Shimmer:APQ5',
#  'MDVP:Shimmer',
#  'MDVP:APQ',
#  'MDVP:Shimmer',
#  'Shimmer:DDA',
#  'MDVP:Shimmer(dB)',
#  'Shimmer:APQ3',
#  'MDVP:Shimmer(dB)',
#  'Shimmer:APQ5',
#  'MDVP:Shimmer(dB)',
#  'MDVP:APQ',
#  'MDVP:Shimmer(dB)',
#  'Shimmer:DDA',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'Shimmer:APQ3',
#  'Shimmer:DDA',
#  'Shimmer:APQ5',
#  'MDVP:APQ',
#  'Shimmer:APQ5',
#  'Shimmer:DDA',
#  'spread1',
#  'PPE']

# %% [markdown]
# The above features are highly correlated. They are repetitions because a high correlation gives a pair of features(one from row and one from the column).

# %%
X = x.values
Y = y.values
feature_names = x.columns


def lasso_regularization(X,Y,feature_names):
    """Function to implement lasso regularization.
    classifiers: List of classifieers
    Inputs:
    X: Array values of input
    Y: Array valeus of output
    feature_names:List of feature names
    
    Ouputs:
    dtf_features: Dataframe which shows the importance of each feature in anaova and lasso method """
    
    ## Anova
    selector = feature_selection.SelectKBest(score_func=  
                   feature_selection.f_classif, k=10).fit(X,Y)
    anova_selected_features = feature_names[selector.get_support()]
    
    ## Lasso regularization
    selector = feature_selection.SelectFromModel(estimator= 
                  linear_model.LogisticRegression(C=1, penalty="l1", 
                  solver='liblinear'), max_features=10).fit(X,Y)
    lasso_selected_features = feature_names[selector.get_support()]
     
    ## Plot
    dtf_features = pd.DataFrame({"features":feature_names})
    dtf_features["anova"] = dtf_features["features"].apply(lambda x: "anova" if x in anova_selected_features else "")
    dtf_features["num1"] = dtf_features["features"].apply(lambda x: 1 if x in anova_selected_features else 0)
    dtf_features["lasso"] = dtf_features["features"].apply(lambda x: "lasso" if x in lasso_selected_features else "")
    dtf_features["num2"] = dtf_features["features"].apply(lambda x: 1 if x in lasso_selected_features else 0)
    dtf_features["method"] = dtf_features[["anova","lasso"]].apply(lambda x: (x[0]+" "+x[1]).strip(), axis=1)
    dtf_features["selection"] = dtf_features["num1"] + dtf_features["num2"]
    return dtf_features

dtf_features=lasso_regularization(X, Y, feature_names)
# 
dtf_features.head()
# Out:
#            features  anova  num1  lasso  num2       method  selection
# 0       MDVP:Fo(Hz)  anova     1  lasso     1  anova lasso          2
# 1      MDVP:Fhi(Hz)            0  lasso     1        lasso          1
# 2      MDVP:Flo(Hz)  anova     1  lasso     1  anova lasso          2
# 3    MDVP:Jitter(%)            0            0                       0
# 4  MDVP:Jitter(Abs)            0            0                       0

# %%
fig=plt.figure(figsize=(18,10))
plt.title("Feature selection based on Lasso regularization and ANOVA")
sns.barplot(y="features", x="selection", hue="method", data=dtf_features.sort_values("selection", ascending=False), dodge=False)
# Out:
# <AxesSubplot:title={'center':'Feature selection based on Lasso regularization and ANOVA'}, xlabel='selection', ylabel='features'>

# %% [markdown]
# The below cell gives the final list of features to be dropped. This done by selecting the feature names to common to features in drop1 and drop2 list.

# %%
# Selecting the least important features from lasso and anova method
drop2=[row['features'] for index,row in dtf_features.iterrows() if all(row[['num1','num2','selection']]==0)]

# The final feature list to drop obtained by finding the common feature names from correlation and anova lasso method
final_drop=set(drop1)& set(drop2)

x=x.drop(columns=final_drop)

# %% [markdown]
# After doing the dimensionality reduction, distribution of the features are checked using distplot.Because less important features are already dropped, plotting distribution plots of features are more computionally efficent as there are less number of features

# %%
# Plotting distribution plot.
fig=plt.figure(figsize=(25,16))
for i,column in enumerate(x.columns):
  fig.add_subplot(7,2,i+1).set_title(column)
  ax=sns.distplot(x[column])

# %% [markdown]
# The pariplot shows that features are skewed and therefore feature scaling is required. The next cell odes the feature scaling of the input features.
# Becuase the input data is skewed, Standardization(z score) is applied to remove the skewness. Min max scaling is not chosen because all the input features are in the same domain(features of sound). Standardization(z scores)or box cox transformation are suitable in thiss case. Hence I chose Standardization as feature scaling.

# %%
# Calculating z scores
x=(x - x.mean(axis=0))/x.std(axis=0)

# %% [markdown]
# ## 4.Data preparation
# There is data imbalance in data set.i.e the number of people having Parkinson is higher than control group. So I used stratify and shuffle option in train_test_split function of sklearn to reduce imbalance and thereby chances of overfitting.

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33,stratify=y,shuffle=True,)

# %%
classifiers=[]
classifiers.append(LogisticRegression(solver='liblinear'))
classifiers.append(SVC(kernel='linear', probability=True))
classifiers.append(GaussianNB())
classifiers.append(DecisionTreeClassifier())
classifiers.append(RandomForestClassifier())
classifiers.append(CatBoostClassifier())

# %% [markdown]
# ## 5. Model Building and Evaluation
# I used six classifiers in thsi section.They are Logistic Regression, Support Vector Machine, Decison tree, Naive Bayes and finally two ensemble algorithms namesly Random forest and Catboost.
# Random forest is an ensemble learning method for classification, regression and other tasks that operates by constructing a multitude of decision trees at training time. This algorithnm works for small data set
# CatBoost is an algorithm for gradient boosting on decision trees. Its a newly developed alogorthm which works non-homogenous dataset and small data sets

# %% [markdown]
# Confusion matrix accuracy= (TP+TN)/(Total samples)
# AUC curve=The Area Under the Curve (AUC) is the measure of the ability of a classifier to distinguish between classes and is used as a summary of the ROC curve.
# The higher the AUC, the better the performance of the model at distinguishing between the positive and negative classes. Higher the area under the curve , better the model.

# %%
models=['Logistic Regression','SVM','Naive Bayes','Decision Tree','Random Forest','CatBoost']
acc_list=[]
auc_list=[]
cm_list=[]

model_fits=[]
def eval_metrics(classifiers):
    """Function to calculate evaluation metrics such as Accuarcy,AUC and Confusion Matrix
    Inputs:
    classifiers: List of classifieers
    Ouputs:
    model_fits: Objects of all models build using fit functionof sklearn
    acc_list: List of accuracy of models
    auc_list:List of AUC of models
    cm_list:List of confusion matrix of models"""
    
    for model in classifiers:
      #Fits the modle to the training data
      model_fits.append(model.fit(X_train,y_train))
      #Predicts the output based on test data
      y_pred=model.predict(X_test)
      # Finding accuracy of the prediction
      acc_list.append(metrics.accuracy_score(y_test,y_pred))
      # Finding flase and true positive rates
      fpr,tpr,_thresholds=metrics.roc_curve(y_test,y_pred,pos_label=model.classes_[1])
      # Finding Area under curve using fpr, and tpr
      auc_list.append(round(metrics.auc(fpr,tpr),2))
      # Finding confusion matrix values
      cm_list.append(confusion_matrix(y_test,y_pred))
      
    return model_fits, acc_list,auc_list,cm_list,

model_fits,acc_list,auc_list,cm_list=eval_metrics(classifiers)
# Out:
# Learning rate set to 0.004311
# 0:	learn: 0.6887372	total: 3.66ms	remaining: 3.65s
# 1:	learn: 0.6855132	total: 7.04ms	remaining: 3.51s
# 2:	learn: 0.6809603	total: 10.4ms	remaining: 3.46s
# 3:	learn: 0.6767438	total: 13.9ms	remaining: 3.46s
# 4:	learn: 0.6722062	total: 17.2ms	remaining: 3.42s
# 5:	learn: 0.6682062	total: 20.6ms	remaining: 3.4s
# 6:	learn: 0.6637478	total: 24ms	remaining: 3.4s
# 7:	learn: 0.6594109	total: 27.3ms	remaining: 3.39s
# 8:	learn: 0.6545465	total: 30.6ms	remaining: 3.37s
# 9:	learn: 0.6497428	total: 34.2ms	remaining: 3.39s
# 10:	learn: 0.6456740	total: 37.6ms	remaining: 3.38s
# 11:	learn: 0.6419618	total: 42.1ms	remaining: 3.47s
# 12:	learn: 0.6379889	total: 45.7ms	remaining: 3.47s
# 13:	learn: 0.6336737	total: 49.2ms	remaining: 3.46s
# 14:	learn: 0.6298016	total: 52.3ms	remaining: 3.43s
# 15:	learn: 0.6259176	total: 55.3ms	remaining: 3.4s
# 16:	learn: 0.6211774	total: 58.2ms	remaining: 3.36s
# 17:	learn: 0.6179826	total: 61ms	remaining: 3.33s
# 18:	learn: 0.6137023	total: 63.8ms	remaining: 3.29s
# 19:	learn: 0.6092492	total: 66.7ms	remaining: 3.27s
# 20:	learn: 0.6058890	total: 69.5ms	remaining: 3.24s
# 21:	learn: 0.6016074	total: 72.3ms	remaining: 3.21s
# 22:	learn: 0.5976029	total: 75.2ms	remaining: 3.19s
# 23:	learn: 0.5938825	total: 78ms	remaining: 3.17s
# 24:	learn: 0.5902467	total: 80.9ms	remaining: 3.15s
# 25:	learn: 0.5860116	total: 83.8ms	remaining: 3.14s
# 26:	learn: 0.5828122	total: 86.6ms	remaining: 3.12s
# 27:	learn: 0.5789064	total: 89.5ms	remaining: 3.11s
# 28:	learn: 0.5747306	total: 92.3ms	remaining: 3.09s
# 29:	learn: 0.5711546	total: 95.1ms	remaining: 3.08s
# 30:	learn: 0.5677005	total: 98ms	remaining: 3.06s
# 31:	learn: 0.5644758	total: 101ms	remaining: 3.05s
# 32:	learn: 0.5617574	total: 104ms	remaining: 3.04s
# 33:	learn: 0.5585059	total: 107ms	remaining: 3.03s
# 34:	learn: 0.5540942	total: 109ms	remaining: 3.02s
# 35:	learn: 0.5503484	total: 112ms	remaining: 3.01s
# 36:	learn: 0.5465938	total: 115ms	remaining: 3s
# 37:	learn: 0.5434312	total: 118ms	remaining: 2.99s
# 38:	learn: 0.5407140	total: 121ms	remaining: 2.98s
# 39:	learn: 0.5379655	total: 124ms	remaining: 2.97s
# 40:	learn: 0.5350157	total: 126ms	remaining: 2.96s
# 41:	learn: 0.5319433	total: 129ms	remaining: 2.95s
# 42:	learn: 0.5287599	total: 132ms	remaining: 2.94s
# 43:	learn: 0.5251246	total: 135ms	remaining: 2.93s
# 44:	learn: 0.5222561	total: 138ms	remaining: 2.92s
# 45:	learn: 0.5190558	total: 141ms	remaining: 2.91s
# 46:	learn: 0.5164923	total: 143ms	remaining: 2.91s
# 47:	learn: 0.5139460	total: 146ms	remaining: 2.9s
# 48:	learn: 0.5115203	total: 149ms	remaining: 2.89s
# 49:	learn: 0.5086753	total: 152ms	remaining: 2.88s
# 50:	learn: 0.5056483	total: 155ms	remaining: 2.88s
# 51:	learn: 0.5023410	total: 157ms	remaining: 2.87s
# 52:	learn: 0.4995218	total: 160ms	remaining: 2.86s
# 53:	learn: 0.4968265	total: 164ms	remaining: 2.87s
# 54:	learn: 0.4940712	total: 167ms	remaining: 2.88s
# 55:	learn: 0.4909328	total: 171ms	remaining: 2.88s
# 56:	learn: 0.4880984	total: 174ms	remaining: 2.88s
# 57:	learn: 0.4849458	total: 179ms	remaining: 2.9s
# 58:	learn: 0.4817787	total: 182ms	remaining: 2.91s
# 59:	learn: 0.4785765	total: 186ms	remaining: 2.91s
# 60:	learn: 0.4754548	total: 189ms	remaining: 2.91s
# 61:	learn: 0.4729262	total: 192ms	remaining: 2.91s
# 62:	learn: 0.4700848	total: 195ms	remaining: 2.9s
# 63:	learn: 0.4677185	total: 198ms	remaining: 2.89s
# 64:	learn: 0.4653932	total: 201ms	remaining: 2.88s
# 65:	learn: 0.4625513	total: 204ms	remaining: 2.88s
# 66:	learn: 0.4598427	total: 207ms	remaining: 2.88s
# 67:	learn: 0.4577493	total: 209ms	remaining: 2.87s
# 68:	learn: 0.4555593	total: 212ms	remaining: 2.86s
# 69:	learn: 0.4532899	total: 215ms	remaining: 2.86s
# 70:	learn: 0.4509795	total: 218ms	remaining: 2.85s
# 71:	learn: 0.4486948	total: 221ms	remaining: 2.84s
# 72:	learn: 0.4464262	total: 223ms	remaining: 2.84s
# 73:	learn: 0.4437356	total: 226ms	remaining: 2.83s
# 74:	learn: 0.4413707	total: 229ms	remaining: 2.83s
# 75:	learn: 0.4389327	total: 232ms	remaining: 2.82s
# 76:	learn: 0.4360967	total: 235ms	remaining: 2.81s
# 77:	learn: 0.4337430	total: 238ms	remaining: 2.81s
# 78:	learn: 0.4313448	total: 240ms	remaining: 2.8s
# 79:	learn: 0.4295439	total: 243ms	remaining: 2.8s
# 80:	learn: 0.4276242	total: 246ms	remaining: 2.79s
# 81:	learn: 0.4251219	total: 249ms	remaining: 2.79s
# 82:	learn: 0.4223846	total: 252ms	remaining: 2.78s
# 83:	learn: 0.4205835	total: 255ms	remaining: 2.77s
# 84:	learn: 0.4183891	total: 257ms	remaining: 2.77s
# 85:	learn: 0.4164635	total: 260ms	remaining: 2.76s
# 86:	learn: 0.4145595	total: 263ms	remaining: 2.76s
# 87:	learn: 0.4124386	total: 266ms	remaining: 2.75s
# 88:	learn: 0.4101201	total: 269ms	remaining: 2.75s
# 89:	learn: 0.4074941	total: 272ms	remaining: 2.75s
# 90:	learn: 0.4049546	total: 274ms	remaining: 2.74s
# 91:	learn: 0.4031245	total: 277ms	remaining: 2.73s
# 92:	learn: 0.4009843	total: 280ms	remaining: 2.73s
# 93:	learn: 0.3985465	total: 283ms	remaining: 2.73s
# 94:	learn: 0.3964637	total: 286ms	remaining: 2.72s
# 95:	learn: 0.3947516	total: 288ms	remaining: 2.71s
# 96:	learn: 0.3927813	total: 291ms	remaining: 2.71s
# 97:	learn: 0.3903147	total: 295ms	remaining: 2.71s
# 98:	learn: 0.3883113	total: 297ms	remaining: 2.71s
# 99:	learn: 0.3862494	total: 300ms	remaining: 2.7s
# 100:	learn: 0.3838319	total: 303ms	remaining: 2.7s
# 101:	learn: 0.3820700	total: 306ms	remaining: 2.69s
# 102:	learn: 0.3800555	total: 309ms	remaining: 2.69s
# 103:	learn: 0.3786781	total: 312ms	remaining: 2.69s
# 104:	learn: 0.3767148	total: 315ms	remaining: 2.68s
# 105:	learn: 0.3749909	total: 317ms	remaining: 2.68s
# 106:	learn: 0.3733778	total: 321ms	remaining: 2.67s
# 107:	learn: 0.3714937	total: 323ms	remaining: 2.67s
# 108:	learn: 0.3695112	total: 326ms	remaining: 2.67s
# 109:	learn: 0.3677836	total: 329ms	remaining: 2.66s
# 110:	learn: 0.3654181	total: 332ms	remaining: 2.66s
# 111:	learn: 0.3633679	total: 335ms	remaining: 2.65s
# 112:	learn: 0.3611123	total: 339ms	remaining: 2.66s
# 113:	learn: 0.3593744	total: 342ms	remaining: 2.66s
# 114:	learn: 0.3575280	total: 345ms	remaining: 2.66s
# 115:	learn: 0.3558880	total: 349ms	remaining: 2.66s
# 116:	learn: 0.3542796	total: 352ms	remaining: 2.66s
# 117:	learn: 0.3528951	total: 358ms	remaining: 2.67s
# 118:	learn: 0.3514548	total: 362ms	remaining: 2.68s
# 119:	learn: 0.3497470	total: 365ms	remaining: 2.68s
# 120:	learn: 0.3480761	total: 368ms	remaining: 2.67s
# 121:	learn: 0.3465189	total: 372ms	remaining: 2.67s
# 122:	learn: 0.3450822	total: 377ms	remaining: 2.69s
# 123:	learn: 0.3433323	total: 381ms	remaining: 2.69s
# 124:	learn: 0.3416664	total: 384ms	remaining: 2.69s
# 125:	learn: 0.3401295	total: 387ms	remaining: 2.68s
# 126:	learn: 0.3387486	total: 391ms	remaining: 2.69s
# 127:	learn: 0.3369983	total: 394ms	remaining: 2.68s
# 128:	learn: 0.3353776	total: 397ms	remaining: 2.68s
# 129:	learn: 0.3336574	total: 400ms	remaining: 2.67s
# 130:	learn: 0.3321871	total: 402ms	remaining: 2.67s
# 131:	learn: 0.3310810	total: 406ms	remaining: 2.67s
# 132:	learn: 0.3293581	total: 409ms	remaining: 2.66s
# 133:	learn: 0.3277818	total: 411ms	remaining: 2.66s
# 134:	learn: 0.3262475	total: 414ms	remaining: 2.65s
# 135:	learn: 0.3242165	total: 417ms	remaining: 2.65s
# 136:	learn: 0.3226637	total: 420ms	remaining: 2.65s
# 137:	learn: 0.3211796	total: 423ms	remaining: 2.64s
# 138:	learn: 0.3196055	total: 426ms	remaining: 2.64s
# 139:	learn: 0.3182635	total: 429ms	remaining: 2.63s
# 140:	learn: 0.3169071	total: 431ms	remaining: 2.63s
# 141:	learn: 0.3155008	total: 434ms	remaining: 2.62s
# 142:	learn: 0.3145689	total: 437ms	remaining: 2.62s
# 143:	learn: 0.3134864	total: 440ms	remaining: 2.61s
# 144:	learn: 0.3117440	total: 443ms	remaining: 2.61s
# 145:	learn: 0.3103935	total: 445ms	remaining: 2.6s
# 146:	learn: 0.3090558	total: 448ms	remaining: 2.6s
# 147:	learn: 0.3075044	total: 451ms	remaining: 2.6s
# 148:	learn: 0.3066884	total: 454ms	remaining: 2.59s
# 149:	learn: 0.3057065	total: 457ms	remaining: 2.59s
# 150:	learn: 0.3042899	total: 460ms	remaining: 2.58s
# 151:	learn: 0.3027375	total: 462ms	remaining: 2.58s
# 152:	learn: 0.3010302	total: 465ms	remaining: 2.58s
# 153:	learn: 0.2997740	total: 468ms	remaining: 2.57s
# 154:	learn: 0.2984873	total: 471ms	remaining: 2.57s
# 155:	learn: 0.2976232	total: 475ms	remaining: 2.57s
# 156:	learn: 0.2963747	total: 478ms	remaining: 2.57s
# 157:	learn: 0.2951077	total: 481ms	remaining: 2.56s
# 158:	learn: 0.2939619	total: 484ms	remaining: 2.56s
# 159:	learn: 0.2927388	total: 487ms	remaining: 2.56s
# 160:	learn: 0.2915711	total: 490ms	remaining: 2.55s
# 161:	learn: 0.2906442	total: 492ms	remaining: 2.55s
# 162:	learn: 0.2891872	total: 495ms	remaining: 2.54s
# 163:	learn: 0.2880258	total: 498ms	remaining: 2.54s
# 164:	learn: 0.2864753	total: 501ms	remaining: 2.54s
# 165:	learn: 0.2853394	total: 504ms	remaining: 2.53s
# 166:	learn: 0.2840521	total: 507ms	remaining: 2.53s
# 167:	learn: 0.2831816	total: 511ms	remaining: 2.53s
# 168:	learn: 0.2819262	total: 514ms	remaining: 2.53s
# 169:	learn: 0.2805515	total: 517ms	remaining: 2.52s
# 170:	learn: 0.2793491	total: 521ms	remaining: 2.52s
# 171:	learn: 0.2782470	total: 524ms	remaining: 2.52s
# 172:	learn: 0.2769502	total: 528ms	remaining: 2.52s
# 173:	learn: 0.2755025	total: 531ms	remaining: 2.52s
# 174:	learn: 0.2744471	total: 534ms	remaining: 2.52s
# 175:	learn: 0.2732417	total: 538ms	remaining: 2.52s
# 176:	learn: 0.2720442	total: 541ms	remaining: 2.52s
# 177:	learn: 0.2705512	total: 545ms	remaining: 2.52s
# 178:	learn: 0.2693041	total: 548ms	remaining: 2.51s
# 179:	learn: 0.2679767	total: 551ms	remaining: 2.51s
# 180:	learn: 0.2669066	total: 554ms	remaining: 2.5s
# 181:	learn: 0.2655841	total: 556ms	remaining: 2.5s
# 182:	learn: 0.2647154	total: 560ms	remaining: 2.5s
# 183:	learn: 0.2638092	total: 562ms	remaining: 2.49s
# 184:	learn: 0.2626685	total: 565ms	remaining: 2.49s
# 185:	learn: 0.2616278	total: 568ms	remaining: 2.49s
# 186:	learn: 0.2608085	total: 571ms	remaining: 2.48s
# 187:	learn: 0.2594983	total: 574ms	remaining: 2.48s
# 188:	learn: 0.2585367	total: 577ms	remaining: 2.47s
# 189:	learn: 0.2573798	total: 579ms	remaining: 2.47s
# 190:	learn: 0.2565728	total: 582ms	remaining: 2.46s
# 191:	learn: 0.2554074	total: 585ms	remaining: 2.46s
# 192:	learn: 0.2543551	total: 588ms	remaining: 2.46s
# 193:	learn: 0.2534732	total: 591ms	remaining: 2.45s
# 194:	learn: 0.2523566	total: 593ms	remaining: 2.45s
# 195:	learn: 0.2514299	total: 596ms	remaining: 2.44s
# 196:	learn: 0.2506125	total: 599ms	remaining: 2.44s
# 197:	learn: 0.2499237	total: 602ms	remaining: 2.44s
# 198:	learn: 0.2491726	total: 605ms	remaining: 2.43s
# 199:	learn: 0.2482054	total: 607ms	remaining: 2.43s
# 200:	learn: 0.2468566	total: 610ms	remaining: 2.42s
# 201:	learn: 0.2456280	total: 613ms	remaining: 2.42s
# 202:	learn: 0.2446782	total: 616ms	remaining: 2.42s
# 203:	learn: 0.2436650	total: 619ms	remaining: 2.41s
# 204:	learn: 0.2426913	total: 622ms	remaining: 2.41s
# 205:	learn: 0.2416422	total: 624ms	remaining: 2.41s
# 206:	learn: 0.2405406	total: 627ms	remaining: 2.4s
# 207:	learn: 0.2396396	total: 630ms	remaining: 2.4s
# 208:	learn: 0.2387639	total: 633ms	remaining: 2.4s
# 209:	learn: 0.2381630	total: 636ms	remaining: 2.39s
# 210:	learn: 0.2371856	total: 639ms	remaining: 2.39s
# 211:	learn: 0.2362029	total: 641ms	remaining: 2.38s
# 212:	learn: 0.2352467	total: 644ms	remaining: 2.38s
# 213:	learn: 0.2345345	total: 647ms	remaining: 2.38s
# 214:	learn: 0.2335258	total: 650ms	remaining: 2.37s
# 215:	learn: 0.2326137	total: 653ms	remaining: 2.37s
# 216:	learn: 0.2317151	total: 655ms	remaining: 2.36s
# 217:	learn: 0.2310464	total: 658ms	remaining: 2.36s
# 218:	learn: 0.2302147	total: 661ms	remaining: 2.36s
# 219:	learn: 0.2291772	total: 664ms	remaining: 2.35s
# 220:	learn: 0.2284058	total: 667ms	remaining: 2.35s
# 221:	learn: 0.2275872	total: 669ms	remaining: 2.35s
# 222:	learn: 0.2266707	total: 672ms	remaining: 2.34s
# 223:	learn: 0.2255582	total: 675ms	remaining: 2.34s
# 224:	learn: 0.2245420	total: 678ms	remaining: 2.33s
# 225:	learn: 0.2237082	total: 681ms	remaining: 2.33s
# 226:	learn: 0.2229221	total: 684ms	remaining: 2.33s
# 227:	learn: 0.2222128	total: 688ms	remaining: 2.33s
# 228:	learn: 0.2214732	total: 691ms	remaining: 2.33s
# 229:	learn: 0.2207109	total: 695ms	remaining: 2.33s
# 230:	learn: 0.2197290	total: 699ms	remaining: 2.33s
# 231:	learn: 0.2190767	total: 702ms	remaining: 2.32s
# 232:	learn: 0.2182726	total: 705ms	remaining: 2.32s
# 233:	learn: 0.2175996	total: 708ms	remaining: 2.32s
# 234:	learn: 0.2167030	total: 711ms	remaining: 2.31s
# 235:	learn: 0.2160147	total: 714ms	remaining: 2.31s
# 236:	learn: 0.2154909	total: 717ms	remaining: 2.31s
# 237:	learn: 0.2148939	total: 720ms	remaining: 2.31s
# 238:	learn: 0.2142411	total: 723ms	remaining: 2.3s
# 239:	learn: 0.2133711	total: 726ms	remaining: 2.3s
# 240:	learn: 0.2126746	total: 729ms	remaining: 2.29s
# 241:	learn: 0.2119654	total: 732ms	remaining: 2.29s
# 242:	learn: 0.2113553	total: 735ms	remaining: 2.29s
# 243:	learn: 0.2106830	total: 738ms	remaining: 2.29s
# 244:	learn: 0.2097322	total: 740ms	remaining: 2.28s
# 245:	learn: 0.2089271	total: 743ms	remaining: 2.28s
# 246:	learn: 0.2079895	total: 746ms	remaining: 2.27s
# 247:	learn: 0.2070786	total: 749ms	remaining: 2.27s
# 248:	learn: 0.2065574	total: 752ms	remaining: 2.27s
# 249:	learn: 0.2057888	total: 755ms	remaining: 2.27s
# 250:	learn: 0.2050777	total: 759ms	remaining: 2.26s
# 251:	learn: 0.2042308	total: 762ms	remaining: 2.26s
# 252:	learn: 0.2036349	total: 765ms	remaining: 2.26s
# 253:	learn: 0.2029018	total: 768ms	remaining: 2.25s
# 254:	learn: 0.2020363	total: 770ms	remaining: 2.25s
# 255:	learn: 0.2013117	total: 773ms	remaining: 2.25s
# 256:	learn: 0.2005484	total: 776ms	remaining: 2.24s
# 257:	learn: 0.1997452	total: 779ms	remaining: 2.24s
# 258:	learn: 0.1989369	total: 782ms	remaining: 2.23s
# 259:	learn: 0.1982087	total: 784ms	remaining: 2.23s
# 260:	learn: 0.1976477	total: 787ms	remaining: 2.23s
# 261:	learn: 0.1968521	total: 790ms	remaining: 2.23s
# 262:	learn: 0.1962687	total: 793ms	remaining: 2.22s
# 263:	learn: 0.1957141	total: 796ms	remaining: 2.22s
# 264:	learn: 0.1948024	total: 799ms	remaining: 2.21s
# 265:	learn: 0.1940111	total: 802ms	remaining: 2.21s
# 266:	learn: 0.1932461	total: 804ms	remaining: 2.21s
# 267:	learn: 0.1925702	total: 807ms	remaining: 2.2s
# 268:	learn: 0.1917049	total: 810ms	remaining: 2.2s
# 269:	learn: 0.1908332	total: 813ms	remaining: 2.2s
# 270:	learn: 0.1901731	total: 816ms	remaining: 2.19s
# 271:	learn: 0.1895168	total: 819ms	remaining: 2.19s
# 272:	learn: 0.1890327	total: 822ms	remaining: 2.19s
# 273:	learn: 0.1882126	total: 825ms	remaining: 2.19s
# 274:	learn: 0.1875147	total: 828ms	remaining: 2.18s
# 275:	learn: 0.1867394	total: 831ms	remaining: 2.18s
# 276:	learn: 0.1859997	total: 834ms	remaining: 2.17s
# 277:	learn: 0.1853276	total: 836ms	remaining: 2.17s
# 278:	learn: 0.1847324	total: 839ms	remaining: 2.17s
# 279:	learn: 0.1840588	total: 842ms	remaining: 2.17s
# 280:	learn: 0.1832337	total: 845ms	remaining: 2.16s
# 281:	learn: 0.1825777	total: 848ms	remaining: 2.16s
# 282:	learn: 0.1819723	total: 851ms	remaining: 2.16s
# 283:	learn: 0.1814383	total: 854ms	remaining: 2.15s
# 284:	learn: 0.1809319	total: 858ms	remaining: 2.15s
# 285:	learn: 0.1802167	total: 862ms	remaining: 2.15s
# 286:	learn: 0.1794433	total: 866ms	remaining: 2.15s
# 287:	learn: 0.1787330	total: 870ms	remaining: 2.15s
# 288:	learn: 0.1779910	total: 874ms	remaining: 2.15s
# 289:	learn: 0.1775104	total: 878ms	remaining: 2.15s
# 290:	learn: 0.1768716	total: 881ms	remaining: 2.15s
# 291:	learn: 0.1762517	total: 884ms	remaining: 2.14s
# 292:	learn: 0.1756858	total: 887ms	remaining: 2.14s
# 293:	learn: 0.1750789	total: 890ms	remaining: 2.14s
# 294:	learn: 0.1745036	total: 893ms	remaining: 2.13s
# 295:	learn: 0.1739468	total: 895ms	remaining: 2.13s
# 296:	learn: 0.1731207	total: 899ms	remaining: 2.13s
# 297:	learn: 0.1725446	total: 901ms	remaining: 2.12s
# 298:	learn: 0.1719587	total: 904ms	remaining: 2.12s
# 299:	learn: 0.1712386	total: 908ms	remaining: 2.12s
# 300:	learn: 0.1707901	total: 910ms	remaining: 2.11s
# 301:	learn: 0.1703285	total: 913ms	remaining: 2.11s
# 302:	learn: 0.1697388	total: 916ms	remaining: 2.11s
# 303:	learn: 0.1691255	total: 919ms	remaining: 2.1s
# 304:	learn: 0.1687012	total: 922ms	remaining: 2.1s
# 305:	learn: 0.1681486	total: 925ms	remaining: 2.1s
# 306:	learn: 0.1677099	total: 927ms	remaining: 2.09s
# 307:	learn: 0.1670222	total: 930ms	remaining: 2.09s
# 308:	learn: 0.1664995	total: 933ms	remaining: 2.09s
# 309:	learn: 0.1659375	total: 936ms	remaining: 2.08s
# 310:	learn: 0.1653962	total: 939ms	remaining: 2.08s
# 311:	learn: 0.1648145	total: 942ms	remaining: 2.08s
# 312:	learn: 0.1643760	total: 946ms	remaining: 2.08s
# 313:	learn: 0.1639289	total: 950ms	remaining: 2.08s
# 314:	learn: 0.1632974	total: 953ms	remaining: 2.07s
# 315:	learn: 0.1626753	total: 956ms	remaining: 2.07s
# 316:	learn: 0.1621595	total: 958ms	remaining: 2.06s
# 317:	learn: 0.1617113	total: 962ms	remaining: 2.06s
# 318:	learn: 0.1611914	total: 964ms	remaining: 2.06s
# 319:	learn: 0.1607118	total: 968ms	remaining: 2.06s
# 320:	learn: 0.1601274	total: 971ms	remaining: 2.05s
# 321:	learn: 0.1596751	total: 974ms	remaining: 2.05s
# 322:	learn: 0.1591356	total: 977ms	remaining: 2.05s
# 323:	learn: 0.1585680	total: 980ms	remaining: 2.04s
# 324:	learn: 0.1579925	total: 983ms	remaining: 2.04s
# 325:	learn: 0.1575997	total: 986ms	remaining: 2.04s
# 326:	learn: 0.1570920	total: 990ms	remaining: 2.04s
# 327:	learn: 0.1567233	total: 993ms	remaining: 2.03s
# 328:	learn: 0.1561681	total: 996ms	remaining: 2.03s
# 329:	learn: 0.1555786	total: 1s	remaining: 2.03s
# 330:	learn: 0.1550274	total: 1s	remaining: 2.03s
# 331:	learn: 0.1545124	total: 1.01s	remaining: 2.03s
# 332:	learn: 0.1540163	total: 1.01s	remaining: 2.02s
# 333:	learn: 0.1532255	total: 1.01s	remaining: 2.02s
# 334:	learn: 0.1527912	total: 1.02s	remaining: 2.02s
# 335:	learn: 0.1521564	total: 1.02s	remaining: 2.02s
# 336:	learn: 0.1516662	total: 1.02s	remaining: 2.02s
# 337:	learn: 0.1511893	total: 1.03s	remaining: 2.01s
# 338:	learn: 0.1507256	total: 1.03s	remaining: 2.02s
# 339:	learn: 0.1501541	total: 1.04s	remaining: 2.02s
# 340:	learn: 0.1495879	total: 1.04s	remaining: 2.01s
# 341:	learn: 0.1490937	total: 1.04s	remaining: 2.01s
# 342:	learn: 0.1485746	total: 1.05s	remaining: 2.01s
# 343:	learn: 0.1480174	total: 1.05s	remaining: 2.01s
# 344:	learn: 0.1474487	total: 1.06s	remaining: 2s
# 345:	learn: 0.1470677	total: 1.06s	remaining: 2s
# 346:	learn: 0.1467437	total: 1.06s	remaining: 2s
# 347:	learn: 0.1463198	total: 1.06s	remaining: 2s
# 348:	learn: 0.1458205	total: 1.07s	remaining: 1.99s
# 349:	learn: 0.1454215	total: 1.07s	remaining: 1.99s
# 350:	learn: 0.1448441	total: 1.07s	remaining: 1.99s
# 351:	learn: 0.1444591	total: 1.08s	remaining: 1.98s
# 352:	learn: 0.1439944	total: 1.08s	remaining: 1.98s
# 353:	learn: 0.1435752	total: 1.08s	remaining: 1.98s
# 354:	learn: 0.1431363	total: 1.09s	remaining: 1.97s
# 355:	learn: 0.1425869	total: 1.09s	remaining: 1.97s
# 356:	learn: 0.1422664	total: 1.09s	remaining: 1.97s
# 357:	learn: 0.1418869	total: 1.09s	remaining: 1.96s
# 358:	learn: 0.1416840	total: 1.1s	remaining: 1.96s
# 359:	learn: 0.1414545	total: 1.1s	remaining: 1.96s
# 360:	learn: 0.1409499	total: 1.1s	remaining: 1.95s
# 361:	learn: 0.1405155	total: 1.11s	remaining: 1.95s
# 362:	learn: 0.1401373	total: 1.11s	remaining: 1.95s
# 363:	learn: 0.1397053	total: 1.11s	remaining: 1.94s
# 364:	learn: 0.1392002	total: 1.11s	remaining: 1.94s
# 365:	learn: 0.1387957	total: 1.12s	remaining: 1.94s
# 366:	learn: 0.1383757	total: 1.12s	remaining: 1.93s
# 367:	learn: 0.1379780	total: 1.12s	remaining: 1.93s
# 368:	learn: 0.1375945	total: 1.13s	remaining: 1.93s
# 369:	learn: 0.1373067	total: 1.13s	remaining: 1.92s
# 370:	learn: 0.1369439	total: 1.13s	remaining: 1.92s
# 371:	learn: 0.1366032	total: 1.14s	remaining: 1.92s
# 372:	learn: 0.1360697	total: 1.14s	remaining: 1.91s
# 373:	learn: 0.1356184	total: 1.14s	remaining: 1.91s
# 374:	learn: 0.1351946	total: 1.14s	remaining: 1.91s
# 375:	learn: 0.1348301	total: 1.15s	remaining: 1.9s
# 376:	learn: 0.1345055	total: 1.15s	remaining: 1.9s
# 377:	learn: 0.1341622	total: 1.15s	remaining: 1.9s
# 378:	learn: 0.1337766	total: 1.16s	remaining: 1.89s
# 379:	learn: 0.1334702	total: 1.16s	remaining: 1.89s
# 380:	learn: 0.1330371	total: 1.16s	remaining: 1.89s
# 381:	learn: 0.1325246	total: 1.16s	remaining: 1.88s
# 382:	learn: 0.1321070	total: 1.17s	remaining: 1.88s
# 383:	learn: 0.1318417	total: 1.17s	remaining: 1.88s
# 384:	learn: 0.1314481	total: 1.17s	remaining: 1.87s
# 385:	learn: 0.1312627	total: 1.18s	remaining: 1.87s
# 386:	learn: 0.1309280	total: 1.18s	remaining: 1.87s
# 387:	learn: 0.1305793	total: 1.18s	remaining: 1.86s
# 388:	learn: 0.1301987	total: 1.19s	remaining: 1.86s
# 389:	learn: 0.1298720	total: 1.19s	remaining: 1.86s
# 390:	learn: 0.1293960	total: 1.19s	remaining: 1.85s
# 391:	learn: 0.1290463	total: 1.19s	remaining: 1.85s
# 392:	learn: 0.1286592	total: 1.2s	remaining: 1.85s
# 393:	learn: 0.1282925	total: 1.2s	remaining: 1.84s
# 394:	learn: 0.1279772	total: 1.2s	remaining: 1.84s
# 395:	learn: 0.1276102	total: 1.21s	remaining: 1.84s
# 396:	learn: 0.1273619	total: 1.21s	remaining: 1.84s
# 397:	learn: 0.1270271	total: 1.21s	remaining: 1.83s
# 398:	learn: 0.1267448	total: 1.22s	remaining: 1.83s
# 399:	learn: 0.1263003	total: 1.22s	remaining: 1.83s
# 400:	learn: 0.1260334	total: 1.22s	remaining: 1.83s
# 401:	learn: 0.1257567	total: 1.23s	remaining: 1.82s
# 402:	learn: 0.1255124	total: 1.23s	remaining: 1.82s
# 403:	learn: 0.1252101	total: 1.23s	remaining: 1.82s
# 404:	learn: 0.1248898	total: 1.23s	remaining: 1.81s
# 405:	learn: 0.1244913	total: 1.24s	remaining: 1.81s
# 406:	learn: 0.1241780	total: 1.24s	remaining: 1.81s
# 407:	learn: 0.1238526	total: 1.24s	remaining: 1.8s
# 408:	learn: 0.1234117	total: 1.25s	remaining: 1.8s
# 409:	learn: 0.1230782	total: 1.25s	remaining: 1.8s
# 410:	learn: 0.1227150	total: 1.25s	remaining: 1.79s
# 411:	learn: 0.1223551	total: 1.25s	remaining: 1.79s
# 412:	learn: 0.1220965	total: 1.26s	remaining: 1.79s
# 413:	learn: 0.1217537	total: 1.26s	remaining: 1.78s
# 414:	learn: 0.1214596	total: 1.26s	remaining: 1.78s
# 415:	learn: 0.1211470	total: 1.27s	remaining: 1.78s
# 416:	learn: 0.1208506	total: 1.27s	remaining: 1.77s
# 417:	learn: 0.1205502	total: 1.27s	remaining: 1.77s
# 418:	learn: 0.1202120	total: 1.28s	remaining: 1.77s
# 419:	learn: 0.1198356	total: 1.28s	remaining: 1.77s
# 420:	learn: 0.1195790	total: 1.28s	remaining: 1.76s
# 421:	learn: 0.1192679	total: 1.28s	remaining: 1.76s
# 422:	learn: 0.1190326	total: 1.29s	remaining: 1.75s
# 423:	learn: 0.1187335	total: 1.29s	remaining: 1.75s
# 424:	learn: 0.1184695	total: 1.29s	remaining: 1.75s
# 425:	learn: 0.1181807	total: 1.29s	remaining: 1.75s
# 426:	learn: 0.1178675	total: 1.3s	remaining: 1.74s
# 427:	learn: 0.1175449	total: 1.3s	remaining: 1.74s
# 428:	learn: 0.1172489	total: 1.3s	remaining: 1.74s
# 429:	learn: 0.1169060	total: 1.31s	remaining: 1.73s
# 430:	learn: 0.1165789	total: 1.31s	remaining: 1.73s
# 431:	learn: 0.1162472	total: 1.31s	remaining: 1.73s
# 432:	learn: 0.1159473	total: 1.31s	remaining: 1.72s
# 433:	learn: 0.1156312	total: 1.32s	remaining: 1.72s
# 434:	learn: 0.1152998	total: 1.32s	remaining: 1.72s
# 435:	learn: 0.1150864	total: 1.32s	remaining: 1.71s
# 436:	learn: 0.1146750	total: 1.33s	remaining: 1.71s
# 437:	learn: 0.1143940	total: 1.33s	remaining: 1.71s
# 438:	learn: 0.1141018	total: 1.33s	remaining: 1.7s
# 439:	learn: 0.1138421	total: 1.34s	remaining: 1.7s
# 440:	learn: 0.1135493	total: 1.34s	remaining: 1.7s
# 441:	learn: 0.1132777	total: 1.34s	remaining: 1.69s
# 442:	learn: 0.1130208	total: 1.34s	remaining: 1.69s
# 443:	learn: 0.1128118	total: 1.35s	remaining: 1.69s
# 444:	learn: 0.1125726	total: 1.35s	remaining: 1.68s
# 445:	learn: 0.1122459	total: 1.35s	remaining: 1.68s
# 446:	learn: 0.1119345	total: 1.36s	remaining: 1.68s
# 447:	learn: 0.1116060	total: 1.36s	remaining: 1.67s
# 448:	learn: 0.1113821	total: 1.36s	remaining: 1.67s
# 449:	learn: 0.1111044	total: 1.36s	remaining: 1.67s
# 450:	learn: 0.1107215	total: 1.37s	remaining: 1.67s
# 451:	learn: 0.1104664	total: 1.37s	remaining: 1.66s
# 452:	learn: 0.1101727	total: 1.37s	remaining: 1.66s
# 453:	learn: 0.1098214	total: 1.38s	remaining: 1.66s
# 454:	learn: 0.1094817	total: 1.38s	remaining: 1.65s
# 455:	learn: 0.1091923	total: 1.38s	remaining: 1.65s
# 456:	learn: 0.1089308	total: 1.39s	remaining: 1.65s
# 457:	learn: 0.1086681	total: 1.39s	remaining: 1.65s
# 458:	learn: 0.1084455	total: 1.4s	remaining: 1.64s
# 459:	learn: 0.1081614	total: 1.4s	remaining: 1.64s
# 460:	learn: 0.1079479	total: 1.4s	remaining: 1.64s
# 461:	learn: 0.1076847	total: 1.4s	remaining: 1.63s
# 462:	learn: 0.1074179	total: 1.41s	remaining: 1.63s
# 463:	learn: 0.1070987	total: 1.41s	remaining: 1.63s
# 464:	learn: 0.1068935	total: 1.41s	remaining: 1.63s
# 465:	learn: 0.1065725	total: 1.42s	remaining: 1.62s
# 466:	learn: 0.1063019	total: 1.42s	remaining: 1.62s
# 467:	learn: 0.1060956	total: 1.42s	remaining: 1.61s
# 468:	learn: 0.1058693	total: 1.42s	remaining: 1.61s
# 469:	learn: 0.1056721	total: 1.43s	remaining: 1.61s
# 470:	learn: 0.1054225	total: 1.43s	remaining: 1.61s
# 471:	learn: 0.1051083	total: 1.43s	remaining: 1.6s
# 472:	learn: 0.1048921	total: 1.44s	remaining: 1.6s
# 473:	learn: 0.1046626	total: 1.44s	remaining: 1.6s
# 474:	learn: 0.1044121	total: 1.44s	remaining: 1.59s
# 475:	learn: 0.1041383	total: 1.44s	remaining: 1.59s
# 476:	learn: 0.1038040	total: 1.45s	remaining: 1.59s
# 477:	learn: 0.1035556	total: 1.45s	remaining: 1.58s
# 478:	learn: 0.1033393	total: 1.45s	remaining: 1.58s
# 479:	learn: 0.1030753	total: 1.46s	remaining: 1.58s
# 480:	learn: 0.1027833	total: 1.46s	remaining: 1.57s
# 481:	learn: 0.1026177	total: 1.46s	remaining: 1.57s
# 482:	learn: 0.1024096	total: 1.47s	remaining: 1.57s
# 483:	learn: 0.1021747	total: 1.47s	remaining: 1.56s
# 484:	learn: 0.1019005	total: 1.47s	remaining: 1.56s
# 485:	learn: 0.1016080	total: 1.47s	remaining: 1.56s
# 486:	learn: 0.1013254	total: 1.48s	remaining: 1.56s
# 487:	learn: 0.1011035	total: 1.48s	remaining: 1.55s
# 488:	learn: 0.1008224	total: 1.48s	remaining: 1.55s
# 489:	learn: 0.1005782	total: 1.49s	remaining: 1.55s
# 490:	learn: 0.1003102	total: 1.49s	remaining: 1.54s
# 491:	learn: 0.1001707	total: 1.49s	remaining: 1.54s
# 492:	learn: 0.0999127	total: 1.49s	remaining: 1.54s
# 493:	learn: 0.0997423	total: 1.5s	remaining: 1.53s
# 494:	learn: 0.0995383	total: 1.5s	remaining: 1.53s
# 495:	learn: 0.0993119	total: 1.5s	remaining: 1.53s
# 496:	learn: 0.0990750	total: 1.51s	remaining: 1.52s
# 497:	learn: 0.0989311	total: 1.51s	remaining: 1.52s
# 498:	learn: 0.0986647	total: 1.51s	remaining: 1.52s
# 499:	learn: 0.0984446	total: 1.51s	remaining: 1.51s
# 500:	learn: 0.0982103	total: 1.52s	remaining: 1.51s
# 501:	learn: 0.0979978	total: 1.52s	remaining: 1.51s
# 502:	learn: 0.0978046	total: 1.52s	remaining: 1.5s
# 503:	learn: 0.0976106	total: 1.53s	remaining: 1.5s
# 504:	learn: 0.0974531	total: 1.53s	remaining: 1.5s
# 505:	learn: 0.0973282	total: 1.53s	remaining: 1.5s
# 506:	learn: 0.0970913	total: 1.53s	remaining: 1.49s
# 507:	learn: 0.0967996	total: 1.54s	remaining: 1.49s
# 508:	learn: 0.0965613	total: 1.54s	remaining: 1.49s
# 509:	learn: 0.0962530	total: 1.54s	remaining: 1.48s
# 510:	learn: 0.0959430	total: 1.55s	remaining: 1.48s
# 511:	learn: 0.0957492	total: 1.55s	remaining: 1.48s
# 512:	learn: 0.0955179	total: 1.55s	remaining: 1.47s
# 513:	learn: 0.0952709	total: 1.56s	remaining: 1.47s
# 514:	learn: 0.0950656	total: 1.56s	remaining: 1.47s
# 515:	learn: 0.0948877	total: 1.56s	remaining: 1.47s
# 516:	learn: 0.0946790	total: 1.57s	remaining: 1.46s
# 517:	learn: 0.0944422	total: 1.57s	remaining: 1.46s
# 518:	learn: 0.0941734	total: 1.57s	remaining: 1.46s
# 519:	learn: 0.0939762	total: 1.58s	remaining: 1.46s
# 520:	learn: 0.0937022	total: 1.58s	remaining: 1.45s
# 521:	learn: 0.0934806	total: 1.58s	remaining: 1.45s
# 522:	learn: 0.0932964	total: 1.59s	remaining: 1.45s
# 523:	learn: 0.0930304	total: 1.59s	remaining: 1.44s
# 524:	learn: 0.0928511	total: 1.59s	remaining: 1.44s
# 525:	learn: 0.0925974	total: 1.59s	remaining: 1.44s
# 526:	learn: 0.0924660	total: 1.6s	remaining: 1.43s
# 527:	learn: 0.0922298	total: 1.6s	remaining: 1.43s
# 528:	learn: 0.0919572	total: 1.6s	remaining: 1.43s
# 529:	learn: 0.0917183	total: 1.61s	remaining: 1.42s
# 530:	learn: 0.0915699	total: 1.61s	remaining: 1.42s
# 531:	learn: 0.0913971	total: 1.61s	remaining: 1.42s
# 532:	learn: 0.0912109	total: 1.61s	remaining: 1.41s
# 533:	learn: 0.0910369	total: 1.62s	remaining: 1.41s
# 534:	learn: 0.0907821	total: 1.62s	remaining: 1.41s
# 535:	learn: 0.0905637	total: 1.62s	remaining: 1.41s
# 536:	learn: 0.0903764	total: 1.63s	remaining: 1.4s
# 537:	learn: 0.0902099	total: 1.63s	remaining: 1.4s
# 538:	learn: 0.0900209	total: 1.63s	remaining: 1.4s
# 539:	learn: 0.0898124	total: 1.63s	remaining: 1.39s
# 540:	learn: 0.0895949	total: 1.64s	remaining: 1.39s
# 541:	learn: 0.0894073	total: 1.64s	remaining: 1.39s
# 542:	learn: 0.0892504	total: 1.64s	remaining: 1.38s
# 543:	learn: 0.0890740	total: 1.65s	remaining: 1.38s
# 544:	learn: 0.0888775	total: 1.65s	remaining: 1.38s
# 545:	learn: 0.0886671	total: 1.65s	remaining: 1.37s
# 546:	learn: 0.0884400	total: 1.66s	remaining: 1.37s
# 547:	learn: 0.0882266	total: 1.66s	remaining: 1.37s
# 548:	learn: 0.0879065	total: 1.66s	remaining: 1.36s
# 549:	learn: 0.0876507	total: 1.66s	remaining: 1.36s
# 550:	learn: 0.0874217	total: 1.67s	remaining: 1.36s
# 551:	learn: 0.0871874	total: 1.67s	remaining: 1.35s
# 552:	learn: 0.0869988	total: 1.67s	remaining: 1.35s
# 553:	learn: 0.0868015	total: 1.68s	remaining: 1.35s
# 554:	learn: 0.0866288	total: 1.68s	remaining: 1.34s
# 555:	learn: 0.0864302	total: 1.68s	remaining: 1.34s
# 556:	learn: 0.0862478	total: 1.68s	remaining: 1.34s
# 557:	learn: 0.0861040	total: 1.69s	remaining: 1.34s
# 558:	learn: 0.0858697	total: 1.69s	remaining: 1.33s
# 559:	learn: 0.0856388	total: 1.69s	remaining: 1.33s
# 560:	learn: 0.0853809	total: 1.7s	remaining: 1.33s
# 561:	learn: 0.0851775	total: 1.7s	remaining: 1.32s
# 562:	learn: 0.0849709	total: 1.7s	remaining: 1.32s
# 563:	learn: 0.0847521	total: 1.7s	remaining: 1.32s
# 564:	learn: 0.0845590	total: 1.71s	remaining: 1.31s
# 565:	learn: 0.0843914	total: 1.71s	remaining: 1.31s
# 566:	learn: 0.0842100	total: 1.71s	remaining: 1.31s
# 567:	learn: 0.0840560	total: 1.72s	remaining: 1.3s
# 568:	learn: 0.0838982	total: 1.72s	remaining: 1.3s
# 569:	learn: 0.0837047	total: 1.72s	remaining: 1.3s
# 570:	learn: 0.0834806	total: 1.72s	remaining: 1.29s
# 571:	learn: 0.0832507	total: 1.73s	remaining: 1.29s
# 572:	learn: 0.0831354	total: 1.73s	remaining: 1.29s
# 573:	learn: 0.0829650	total: 1.73s	remaining: 1.29s
# 574:	learn: 0.0827027	total: 1.74s	remaining: 1.28s
# 575:	learn: 0.0825534	total: 1.74s	remaining: 1.28s
# 576:	learn: 0.0823546	total: 1.74s	remaining: 1.28s
# 577:	learn: 0.0820753	total: 1.75s	remaining: 1.27s
# 578:	learn: 0.0818156	total: 1.75s	remaining: 1.27s
# 579:	learn: 0.0816491	total: 1.75s	remaining: 1.27s
# 580:	learn: 0.0815106	total: 1.75s	remaining: 1.26s
# 581:	learn: 0.0813549	total: 1.76s	remaining: 1.26s
# 582:	learn: 0.0811652	total: 1.76s	remaining: 1.26s
# 583:	learn: 0.0809945	total: 1.76s	remaining: 1.26s
# 584:	learn: 0.0807643	total: 1.77s	remaining: 1.25s
# 585:	learn: 0.0806099	total: 1.77s	remaining: 1.25s
# 586:	learn: 0.0804847	total: 1.77s	remaining: 1.25s
# 587:	learn: 0.0802853	total: 1.78s	remaining: 1.25s
# 588:	learn: 0.0800806	total: 1.78s	remaining: 1.24s
# 589:	learn: 0.0799225	total: 1.78s	remaining: 1.24s
# 590:	learn: 0.0797695	total: 1.78s	remaining: 1.24s
# 591:	learn: 0.0796027	total: 1.79s	remaining: 1.23s
# 592:	learn: 0.0794656	total: 1.79s	remaining: 1.23s
# 593:	learn: 0.0791960	total: 1.79s	remaining: 1.23s
# 594:	learn: 0.0790008	total: 1.8s	remaining: 1.22s
# 595:	learn: 0.0788042	total: 1.8s	remaining: 1.22s
# 596:	learn: 0.0786860	total: 1.8s	remaining: 1.22s
# 597:	learn: 0.0785304	total: 1.8s	remaining: 1.21s
# 598:	learn: 0.0784047	total: 1.81s	remaining: 1.21s
# 599:	learn: 0.0783011	total: 1.81s	remaining: 1.21s
# 600:	learn: 0.0782063	total: 1.81s	remaining: 1.2s
# 601:	learn: 0.0780448	total: 1.82s	remaining: 1.2s
# 602:	learn: 0.0778462	total: 1.82s	remaining: 1.2s
# 603:	learn: 0.0777062	total: 1.82s	remaining: 1.2s
# 604:	learn: 0.0775462	total: 1.83s	remaining: 1.19s
# 605:	learn: 0.0773222	total: 1.83s	remaining: 1.19s
# 606:	learn: 0.0771755	total: 1.83s	remaining: 1.19s
# 607:	learn: 0.0769875	total: 1.83s	remaining: 1.18s
# 608:	learn: 0.0768140	total: 1.84s	remaining: 1.18s
# 609:	learn: 0.0766900	total: 1.84s	remaining: 1.18s
# 610:	learn: 0.0765064	total: 1.84s	remaining: 1.17s
# 611:	learn: 0.0763891	total: 1.85s	remaining: 1.17s
# 612:	learn: 0.0761730	total: 1.85s	remaining: 1.17s
# 613:	learn: 0.0759653	total: 1.85s	remaining: 1.16s
# 614:	learn: 0.0757890	total: 1.85s	remaining: 1.16s
# 615:	learn: 0.0756747	total: 1.86s	remaining: 1.16s
# 616:	learn: 0.0755179	total: 1.86s	remaining: 1.15s
# 617:	learn: 0.0753257	total: 1.86s	remaining: 1.15s
# 618:	learn: 0.0751687	total: 1.87s	remaining: 1.15s
# 619:	learn: 0.0750411	total: 1.87s	remaining: 1.15s
# 620:	learn: 0.0748633	total: 1.87s	remaining: 1.14s
# 621:	learn: 0.0747041	total: 1.87s	remaining: 1.14s
# 622:	learn: 0.0746031	total: 1.88s	remaining: 1.14s
# 623:	learn: 0.0744289	total: 1.88s	remaining: 1.13s
# 624:	learn: 0.0742138	total: 1.88s	remaining: 1.13s
# 625:	learn: 0.0740782	total: 1.89s	remaining: 1.13s
# 626:	learn: 0.0739185	total: 1.89s	remaining: 1.12s
# 627:	learn: 0.0737968	total: 1.89s	remaining: 1.12s
# 628:	learn: 0.0736645	total: 1.89s	remaining: 1.12s
# 629:	learn: 0.0734717	total: 1.9s	remaining: 1.11s
# 630:	learn: 0.0734043	total: 1.9s	remaining: 1.11s
# 631:	learn: 0.0732291	total: 1.91s	remaining: 1.11s
# 632:	learn: 0.0730964	total: 1.91s	remaining: 1.11s
# 633:	learn: 0.0729209	total: 1.91s	remaining: 1.1s
# 634:	learn: 0.0727529	total: 1.92s	remaining: 1.1s
# 635:	learn: 0.0726547	total: 1.92s	remaining: 1.1s
# 636:	learn: 0.0725690	total: 1.92s	remaining: 1.09s
# 637:	learn: 0.0724345	total: 1.92s	remaining: 1.09s
# 638:	learn: 0.0722900	total: 1.93s	remaining: 1.09s
# 639:	learn: 0.0721696	total: 1.93s	remaining: 1.08s
# 640:	learn: 0.0720018	total: 1.93s	remaining: 1.08s
# 641:	learn: 0.0718620	total: 1.94s	remaining: 1.08s
# 642:	learn: 0.0717498	total: 1.94s	remaining: 1.08s
# 643:	learn: 0.0715885	total: 1.94s	remaining: 1.07s
# 644:	learn: 0.0714177	total: 1.95s	remaining: 1.07s
# 645:	learn: 0.0713168	total: 1.95s	remaining: 1.07s
# 646:	learn: 0.0711369	total: 1.95s	remaining: 1.06s
# 647:	learn: 0.0710345	total: 1.95s	remaining: 1.06s
# 648:	learn: 0.0708598	total: 1.96s	remaining: 1.06s
# 649:	learn: 0.0706511	total: 1.96s	remaining: 1.05s
# 650:	learn: 0.0705313	total: 1.96s	remaining: 1.05s
# 651:	learn: 0.0703746	total: 1.97s	remaining: 1.05s
# 652:	learn: 0.0702118	total: 1.97s	remaining: 1.04s
# 653:	learn: 0.0700141	total: 1.97s	remaining: 1.04s
# 654:	learn: 0.0698962	total: 1.97s	remaining: 1.04s
# 655:	learn: 0.0697280	total: 1.98s	remaining: 1.04s
# 656:	learn: 0.0696015	total: 1.98s	remaining: 1.03s
# 657:	learn: 0.0693956	total: 1.98s	remaining: 1.03s
# 658:	learn: 0.0692319	total: 1.99s	remaining: 1.03s
# 659:	learn: 0.0690765	total: 1.99s	remaining: 1.02s
# 660:	learn: 0.0689697	total: 1.99s	remaining: 1.02s
# 661:	learn: 0.0688041	total: 2s	remaining: 1.02s
# 662:	learn: 0.0686536	total: 2s	remaining: 1.02s
# 663:	learn: 0.0685584	total: 2s	remaining: 1.01s
# 664:	learn: 0.0683574	total: 2.01s	remaining: 1.01s
# 665:	learn: 0.0682342	total: 2.01s	remaining: 1.01s
# 666:	learn: 0.0681040	total: 2.02s	remaining: 1.01s
# 667:	learn: 0.0680045	total: 2.02s	remaining: 1s
# 668:	learn: 0.0678646	total: 2.02s	remaining: 1s
# 669:	learn: 0.0677566	total: 2.02s	remaining: 998ms
# 670:	learn: 0.0676343	total: 2.03s	remaining: 995ms
# 671:	learn: 0.0675144	total: 2.03s	remaining: 993ms
# 672:	learn: 0.0674060	total: 2.04s	remaining: 989ms
# 673:	learn: 0.0672953	total: 2.04s	remaining: 986ms
# 674:	learn: 0.0671656	total: 2.04s	remaining: 983ms
# 675:	learn: 0.0670192	total: 2.04s	remaining: 980ms
# 676:	learn: 0.0668805	total: 2.05s	remaining: 977ms
# 677:	learn: 0.0667734	total: 2.05s	remaining: 974ms
# 678:	learn: 0.0665990	total: 2.05s	remaining: 971ms
# 679:	learn: 0.0664700	total: 2.06s	remaining: 968ms
# 680:	learn: 0.0663265	total: 2.06s	remaining: 964ms
# 681:	learn: 0.0661447	total: 2.06s	remaining: 961ms
# 682:	learn: 0.0659655	total: 2.06s	remaining: 958ms
# 683:	learn: 0.0658447	total: 2.07s	remaining: 955ms
# 684:	learn: 0.0657684	total: 2.07s	remaining: 953ms
# 685:	learn: 0.0656513	total: 2.08s	remaining: 950ms
# 686:	learn: 0.0655254	total: 2.08s	remaining: 947ms
# 687:	learn: 0.0653784	total: 2.08s	remaining: 944ms
# 688:	learn: 0.0652940	total: 2.08s	remaining: 941ms
# 689:	learn: 0.0651262	total: 2.09s	remaining: 938ms
# 690:	learn: 0.0650235	total: 2.09s	remaining: 936ms
# 691:	learn: 0.0648791	total: 2.1s	remaining: 933ms
# 692:	learn: 0.0647534	total: 2.1s	remaining: 930ms
# 693:	learn: 0.0646907	total: 2.1s	remaining: 927ms
# 694:	learn: 0.0645677	total: 2.1s	remaining: 923ms
# 695:	learn: 0.0643875	total: 2.11s	remaining: 920ms
# 696:	learn: 0.0642692	total: 2.11s	remaining: 917ms
# 697:	learn: 0.0641415	total: 2.11s	remaining: 914ms
# 698:	learn: 0.0640184	total: 2.12s	remaining: 911ms
# 699:	learn: 0.0638852	total: 2.12s	remaining: 908ms
# 700:	learn: 0.0637888	total: 2.12s	remaining: 905ms
# 701:	learn: 0.0636414	total: 2.13s	remaining: 902ms
# 702:	learn: 0.0635418	total: 2.13s	remaining: 899ms
# 703:	learn: 0.0634353	total: 2.13s	remaining: 896ms
# 704:	learn: 0.0633543	total: 2.13s	remaining: 893ms
# 705:	learn: 0.0631952	total: 2.14s	remaining: 890ms
# 706:	learn: 0.0630389	total: 2.14s	remaining: 887ms
# 707:	learn: 0.0629076	total: 2.14s	remaining: 884ms
# 708:	learn: 0.0627608	total: 2.15s	remaining: 880ms
# 709:	learn: 0.0626232	total: 2.15s	remaining: 877ms
# 710:	learn: 0.0624993	total: 2.15s	remaining: 874ms
# 711:	learn: 0.0623804	total: 2.15s	remaining: 871ms
# 712:	learn: 0.0622410	total: 2.16s	remaining: 868ms
# 713:	learn: 0.0621255	total: 2.16s	remaining: 865ms
# 714:	learn: 0.0620563	total: 2.16s	remaining: 862ms
# 715:	learn: 0.0619718	total: 2.17s	remaining: 859ms
# 716:	learn: 0.0618656	total: 2.17s	remaining: 856ms
# 717:	learn: 0.0617580	total: 2.17s	remaining: 853ms
# 718:	learn: 0.0616495	total: 2.17s	remaining: 850ms
# 719:	learn: 0.0615618	total: 2.18s	remaining: 847ms
# 720:	learn: 0.0614660	total: 2.18s	remaining: 844ms
# 721:	learn: 0.0613204	total: 2.18s	remaining: 840ms
# 722:	learn: 0.0612087	total: 2.19s	remaining: 838ms
# 723:	learn: 0.0611357	total: 2.19s	remaining: 834ms
# 724:	learn: 0.0610197	total: 2.19s	remaining: 831ms
# 725:	learn: 0.0609422	total: 2.19s	remaining: 828ms
# 726:	learn: 0.0608227	total: 2.2s	remaining: 825ms
# 727:	learn: 0.0607346	total: 2.2s	remaining: 822ms
# 728:	learn: 0.0606357	total: 2.2s	remaining: 819ms
# 729:	learn: 0.0605363	total: 2.21s	remaining: 816ms
# 730:	learn: 0.0604385	total: 2.21s	remaining: 813ms
# 731:	learn: 0.0603129	total: 2.21s	remaining: 810ms
# 732:	learn: 0.0602203	total: 2.21s	remaining: 807ms
# 733:	learn: 0.0601335	total: 2.22s	remaining: 804ms
# 734:	learn: 0.0600045	total: 2.22s	remaining: 801ms
# 735:	learn: 0.0599271	total: 2.22s	remaining: 798ms
# 736:	learn: 0.0598407	total: 2.23s	remaining: 795ms
# 737:	learn: 0.0597194	total: 2.23s	remaining: 791ms
# 738:	learn: 0.0596128	total: 2.23s	remaining: 788ms
# 739:	learn: 0.0595361	total: 2.23s	remaining: 785ms
# 740:	learn: 0.0594541	total: 2.24s	remaining: 782ms
# 741:	learn: 0.0593165	total: 2.24s	remaining: 779ms
# 742:	learn: 0.0591917	total: 2.24s	remaining: 776ms
# 743:	learn: 0.0591058	total: 2.25s	remaining: 773ms
# 744:	learn: 0.0589783	total: 2.25s	remaining: 770ms
# 745:	learn: 0.0588533	total: 2.25s	remaining: 768ms
# 746:	learn: 0.0587099	total: 2.26s	remaining: 765ms
# 747:	learn: 0.0586680	total: 2.26s	remaining: 762ms
# 748:	learn: 0.0585649	total: 2.26s	remaining: 759ms
# 749:	learn: 0.0584163	total: 2.27s	remaining: 756ms
# 750:	learn: 0.0583322	total: 2.27s	remaining: 753ms
# 751:	learn: 0.0582407	total: 2.27s	remaining: 750ms
# 752:	learn: 0.0581189	total: 2.28s	remaining: 747ms
# 753:	learn: 0.0580241	total: 2.28s	remaining: 744ms
# 754:	learn: 0.0579333	total: 2.28s	remaining: 741ms
# 755:	learn: 0.0578446	total: 2.29s	remaining: 738ms
# 756:	learn: 0.0577767	total: 2.29s	remaining: 734ms
# 757:	learn: 0.0576773	total: 2.29s	remaining: 731ms
# 758:	learn: 0.0575751	total: 2.29s	remaining: 728ms
# 759:	learn: 0.0574944	total: 2.3s	remaining: 725ms
# 760:	learn: 0.0573485	total: 2.3s	remaining: 722ms
# 761:	learn: 0.0572534	total: 2.3s	remaining: 719ms
# 762:	learn: 0.0571737	total: 2.31s	remaining: 716ms
# 763:	learn: 0.0571219	total: 2.31s	remaining: 713ms
# 764:	learn: 0.0570336	total: 2.31s	remaining: 710ms
# 765:	learn: 0.0569443	total: 2.31s	remaining: 707ms
# 766:	learn: 0.0568291	total: 2.32s	remaining: 704ms
# 767:	learn: 0.0567284	total: 2.32s	remaining: 701ms
# 768:	learn: 0.0566113	total: 2.32s	remaining: 698ms
# 769:	learn: 0.0564677	total: 2.33s	remaining: 695ms
# 770:	learn: 0.0563573	total: 2.33s	remaining: 691ms
# 771:	learn: 0.0562517	total: 2.33s	remaining: 688ms
# 772:	learn: 0.0561456	total: 2.33s	remaining: 685ms
# 773:	learn: 0.0560518	total: 2.34s	remaining: 682ms
# 774:	learn: 0.0559601	total: 2.34s	remaining: 679ms
# 775:	learn: 0.0558707	total: 2.34s	remaining: 676ms
# 776:	learn: 0.0557431	total: 2.35s	remaining: 673ms
# 777:	learn: 0.0556734	total: 2.35s	remaining: 670ms
# 778:	learn: 0.0555593	total: 2.35s	remaining: 667ms
# 779:	learn: 0.0554704	total: 2.35s	remaining: 664ms
# 780:	learn: 0.0553919	total: 2.36s	remaining: 661ms
# 781:	learn: 0.0553091	total: 2.36s	remaining: 658ms
# 782:	learn: 0.0552511	total: 2.36s	remaining: 655ms
# 783:	learn: 0.0551283	total: 2.37s	remaining: 652ms
# 784:	learn: 0.0550428	total: 2.37s	remaining: 649ms
# 785:	learn: 0.0549710	total: 2.37s	remaining: 646ms
# 786:	learn: 0.0548511	total: 2.37s	remaining: 643ms
# 787:	learn: 0.0547354	total: 2.38s	remaining: 640ms
# 788:	learn: 0.0546414	total: 2.38s	remaining: 636ms
# 789:	learn: 0.0545336	total: 2.38s	remaining: 633ms
# 790:	learn: 0.0544605	total: 2.38s	remaining: 630ms
# 791:	learn: 0.0543629	total: 2.39s	remaining: 627ms
# 792:	learn: 0.0542391	total: 2.39s	remaining: 624ms
# 793:	learn: 0.0541174	total: 2.39s	remaining: 621ms
# 794:	learn: 0.0540660	total: 2.4s	remaining: 618ms
# 795:	learn: 0.0539513	total: 2.4s	remaining: 615ms
# 796:	learn: 0.0538438	total: 2.4s	remaining: 612ms
# 797:	learn: 0.0537635	total: 2.41s	remaining: 609ms
# 798:	learn: 0.0536671	total: 2.41s	remaining: 606ms
# 799:	learn: 0.0535702	total: 2.41s	remaining: 603ms
# 800:	learn: 0.0534911	total: 2.42s	remaining: 600ms
# 801:	learn: 0.0533923	total: 2.42s	remaining: 597ms
# 802:	learn: 0.0532718	total: 2.42s	remaining: 594ms
# 803:	learn: 0.0531811	total: 2.43s	remaining: 591ms
# 804:	learn: 0.0530918	total: 2.43s	remaining: 589ms
# 805:	learn: 0.0530117	total: 2.43s	remaining: 586ms
# 806:	learn: 0.0529111	total: 2.44s	remaining: 583ms
# 807:	learn: 0.0528150	total: 2.44s	remaining: 580ms
# 808:	learn: 0.0527456	total: 2.44s	remaining: 577ms
# 809:	learn: 0.0526548	total: 2.45s	remaining: 574ms
# 810:	learn: 0.0525543	total: 2.45s	remaining: 571ms
# 811:	learn: 0.0524491	total: 2.45s	remaining: 568ms
# 812:	learn: 0.0523008	total: 2.45s	remaining: 565ms
# 813:	learn: 0.0521958	total: 2.46s	remaining: 562ms
# 814:	learn: 0.0521289	total: 2.46s	remaining: 559ms
# 815:	learn: 0.0520483	total: 2.46s	remaining: 555ms
# 816:	learn: 0.0519960	total: 2.47s	remaining: 552ms
# 817:	learn: 0.0518756	total: 2.47s	remaining: 549ms
# 818:	learn: 0.0517920	total: 2.47s	remaining: 546ms
# 819:	learn: 0.0516783	total: 2.47s	remaining: 543ms
# 820:	learn: 0.0515675	total: 2.48s	remaining: 540ms
# 821:	learn: 0.0514949	total: 2.48s	remaining: 537ms
# 822:	learn: 0.0514270	total: 2.48s	remaining: 534ms
# 823:	learn: 0.0513292	total: 2.49s	remaining: 531ms
# 824:	learn: 0.0512529	total: 2.49s	remaining: 528ms
# 825:	learn: 0.0511839	total: 2.49s	remaining: 525ms
# 826:	learn: 0.0511016	total: 2.5s	remaining: 522ms
# 827:	learn: 0.0509988	total: 2.5s	remaining: 519ms
# 828:	learn: 0.0508881	total: 2.5s	remaining: 516ms
# 829:	learn: 0.0508351	total: 2.5s	remaining: 513ms
# 830:	learn: 0.0507543	total: 2.51s	remaining: 510ms
# 831:	learn: 0.0506733	total: 2.51s	remaining: 507ms
# 832:	learn: 0.0505996	total: 2.51s	remaining: 504ms
# 833:	learn: 0.0505000	total: 2.52s	remaining: 501ms
# 834:	learn: 0.0504133	total: 2.52s	remaining: 498ms
# 835:	learn: 0.0503146	total: 2.52s	remaining: 495ms
# 836:	learn: 0.0502195	total: 2.52s	remaining: 492ms
# 837:	learn: 0.0501155	total: 2.53s	remaining: 489ms
# 838:	learn: 0.0500482	total: 2.53s	remaining: 486ms
# 839:	learn: 0.0499506	total: 2.53s	remaining: 483ms
# 840:	learn: 0.0498807	total: 2.54s	remaining: 479ms
# 841:	learn: 0.0497940	total: 2.54s	remaining: 476ms
# 842:	learn: 0.0496900	total: 2.54s	remaining: 473ms
# 843:	learn: 0.0496122	total: 2.54s	remaining: 470ms
# 844:	learn: 0.0495164	total: 2.55s	remaining: 467ms
# 845:	learn: 0.0494450	total: 2.55s	remaining: 464ms
# 846:	learn: 0.0493592	total: 2.55s	remaining: 461ms
# 847:	learn: 0.0492816	total: 2.56s	remaining: 458ms
# 848:	learn: 0.0491946	total: 2.56s	remaining: 455ms
# 849:	learn: 0.0491169	total: 2.56s	remaining: 452ms
# 850:	learn: 0.0489984	total: 2.56s	remaining: 449ms
# 851:	learn: 0.0488830	total: 2.57s	remaining: 446ms
# 852:	learn: 0.0487662	total: 2.57s	remaining: 443ms
# 853:	learn: 0.0486721	total: 2.57s	remaining: 440ms
# 854:	learn: 0.0486067	total: 2.58s	remaining: 437ms
# 855:	learn: 0.0485147	total: 2.58s	remaining: 434ms
# 856:	learn: 0.0484479	total: 2.58s	remaining: 431ms
# 857:	learn: 0.0483819	total: 2.59s	remaining: 428ms
# 858:	learn: 0.0482869	total: 2.59s	remaining: 425ms
# 859:	learn: 0.0481803	total: 2.59s	remaining: 422ms
# 860:	learn: 0.0481157	total: 2.6s	remaining: 419ms
# 861:	learn: 0.0480019	total: 2.6s	remaining: 416ms
# 862:	learn: 0.0479333	total: 2.6s	remaining: 413ms
# 863:	learn: 0.0478632	total: 2.61s	remaining: 410ms
# 864:	learn: 0.0477708	total: 2.61s	remaining: 407ms
# 865:	learn: 0.0477052	total: 2.61s	remaining: 404ms
# 866:	learn: 0.0476330	total: 2.61s	remaining: 401ms
# 867:	learn: 0.0475676	total: 2.62s	remaining: 398ms
# 868:	learn: 0.0474681	total: 2.62s	remaining: 395ms
# 869:	learn: 0.0473777	total: 2.62s	remaining: 392ms
# 870:	learn: 0.0472855	total: 2.63s	remaining: 389ms
# 871:	learn: 0.0471937	total: 2.63s	remaining: 386ms
# 872:	learn: 0.0471078	total: 2.63s	remaining: 383ms
# 873:	learn: 0.0470255	total: 2.63s	remaining: 380ms
# 874:	learn: 0.0469658	total: 2.64s	remaining: 377ms
# 875:	learn: 0.0468677	total: 2.64s	remaining: 374ms
# 876:	learn: 0.0467712	total: 2.64s	remaining: 371ms
# 877:	learn: 0.0467093	total: 2.65s	remaining: 368ms
# 878:	learn: 0.0466481	total: 2.65s	remaining: 365ms
# 879:	learn: 0.0465769	total: 2.65s	remaining: 362ms
# 880:	learn: 0.0464890	total: 2.65s	remaining: 359ms
# 881:	learn: 0.0464120	total: 2.66s	remaining: 356ms
# 882:	learn: 0.0463246	total: 2.66s	remaining: 353ms
# 883:	learn: 0.0462573	total: 2.66s	remaining: 350ms
# 884:	learn: 0.0461713	total: 2.67s	remaining: 347ms
# 885:	learn: 0.0461220	total: 2.67s	remaining: 344ms
# 886:	learn: 0.0460476	total: 2.67s	remaining: 340ms
# 887:	learn: 0.0460157	total: 2.67s	remaining: 337ms
# 888:	learn: 0.0459161	total: 2.68s	remaining: 334ms
# 889:	learn: 0.0458261	total: 2.68s	remaining: 331ms
# 890:	learn: 0.0457668	total: 2.68s	remaining: 328ms
# 891:	learn: 0.0456874	total: 2.69s	remaining: 325ms
# 892:	learn: 0.0456477	total: 2.69s	remaining: 322ms
# 893:	learn: 0.0455991	total: 2.69s	remaining: 319ms
# 894:	learn: 0.0455061	total: 2.69s	remaining: 316ms
# 895:	learn: 0.0454551	total: 2.7s	remaining: 313ms
# 896:	learn: 0.0453869	total: 2.7s	remaining: 310ms
# 897:	learn: 0.0452843	total: 2.7s	remaining: 307ms
# 898:	learn: 0.0451964	total: 2.71s	remaining: 304ms
# 899:	learn: 0.0451178	total: 2.71s	remaining: 301ms
# 900:	learn: 0.0450362	total: 2.71s	remaining: 298ms
# 901:	learn: 0.0449583	total: 2.71s	remaining: 295ms
# 902:	learn: 0.0449316	total: 2.72s	remaining: 292ms
# 903:	learn: 0.0448662	total: 2.72s	remaining: 289ms
# 904:	learn: 0.0448095	total: 2.72s	remaining: 286ms
# 905:	learn: 0.0447418	total: 2.73s	remaining: 283ms
# 906:	learn: 0.0446783	total: 2.73s	remaining: 280ms
# 907:	learn: 0.0446034	total: 2.73s	remaining: 277ms
# 908:	learn: 0.0445503	total: 2.73s	remaining: 274ms
# 909:	learn: 0.0445104	total: 2.74s	remaining: 271ms
# 910:	learn: 0.0444465	total: 2.74s	remaining: 268ms
# 911:	learn: 0.0443681	total: 2.75s	remaining: 265ms
# 912:	learn: 0.0443250	total: 2.75s	remaining: 262ms
# 913:	learn: 0.0442670	total: 2.75s	remaining: 259ms
# 914:	learn: 0.0441813	total: 2.76s	remaining: 256ms
# 915:	learn: 0.0441032	total: 2.76s	remaining: 253ms
# 916:	learn: 0.0440439	total: 2.76s	remaining: 250ms
# 917:	learn: 0.0439712	total: 2.77s	remaining: 247ms
# 918:	learn: 0.0438900	total: 2.77s	remaining: 244ms
# 919:	learn: 0.0438162	total: 2.77s	remaining: 241ms
# 920:	learn: 0.0437503	total: 2.77s	remaining: 238ms
# 921:	learn: 0.0436842	total: 2.78s	remaining: 235ms
# 922:	learn: 0.0436252	total: 2.78s	remaining: 232ms
# 923:	learn: 0.0435485	total: 2.78s	remaining: 229ms
# 924:	learn: 0.0434929	total: 2.79s	remaining: 226ms
# 925:	learn: 0.0434525	total: 2.79s	remaining: 223ms
# 926:	learn: 0.0434212	total: 2.79s	remaining: 220ms
# 927:	learn: 0.0433493	total: 2.79s	remaining: 217ms
# 928:	learn: 0.0432829	total: 2.8s	remaining: 214ms
# 929:	learn: 0.0432107	total: 2.8s	remaining: 211ms
# 930:	learn: 0.0431247	total: 2.8s	remaining: 208ms
# 931:	learn: 0.0430773	total: 2.81s	remaining: 205ms
# 932:	learn: 0.0430233	total: 2.81s	remaining: 202ms
# 933:	learn: 0.0429674	total: 2.81s	remaining: 199ms
# 934:	learn: 0.0429126	total: 2.81s	remaining: 196ms
# 935:	learn: 0.0428506	total: 2.82s	remaining: 193ms
# 936:	learn: 0.0427965	total: 2.82s	remaining: 190ms
# 937:	learn: 0.0427162	total: 2.82s	remaining: 187ms
# 938:	learn: 0.0426700	total: 2.83s	remaining: 184ms
# 939:	learn: 0.0426239	total: 2.83s	remaining: 181ms
# 940:	learn: 0.0425289	total: 2.83s	remaining: 178ms
# 941:	learn: 0.0424665	total: 2.83s	remaining: 175ms
# 942:	learn: 0.0424261	total: 2.84s	remaining: 172ms
# 943:	learn: 0.0423929	total: 2.84s	remaining: 169ms
# 944:	learn: 0.0423254	total: 2.84s	remaining: 166ms
# 945:	learn: 0.0422653	total: 2.85s	remaining: 163ms
# 946:	learn: 0.0421979	total: 2.85s	remaining: 159ms
# 947:	learn: 0.0421235	total: 2.85s	remaining: 156ms
# 948:	learn: 0.0420600	total: 2.85s	remaining: 153ms
# 949:	learn: 0.0419821	total: 2.86s	remaining: 150ms
# 950:	learn: 0.0419490	total: 2.86s	remaining: 147ms
# 951:	learn: 0.0418939	total: 2.86s	remaining: 144ms
# 952:	learn: 0.0418239	total: 2.87s	remaining: 141ms
# 953:	learn: 0.0417499	total: 2.87s	remaining: 138ms
# 954:	learn: 0.0416886	total: 2.87s	remaining: 135ms
# 955:	learn: 0.0416192	total: 2.88s	remaining: 132ms
# 956:	learn: 0.0415717	total: 2.88s	remaining: 129ms
# 957:	learn: 0.0415281	total: 2.88s	remaining: 126ms
# 958:	learn: 0.0414692	total: 2.88s	remaining: 123ms
# 959:	learn: 0.0414321	total: 2.89s	remaining: 120ms
# 960:	learn: 0.0413808	total: 2.89s	remaining: 117ms
# 961:	learn: 0.0413005	total: 2.89s	remaining: 114ms
# 962:	learn: 0.0412633	total: 2.9s	remaining: 111ms
# 963:	learn: 0.0411888	total: 2.9s	remaining: 108ms
# 964:	learn: 0.0411477	total: 2.9s	remaining: 105ms
# 965:	learn: 0.0410727	total: 2.9s	remaining: 102ms
# 966:	learn: 0.0410005	total: 2.91s	remaining: 99.2ms
# 967:	learn: 0.0409384	total: 2.91s	remaining: 96.2ms
# 968:	learn: 0.0408861	total: 2.91s	remaining: 93.2ms
# 969:	learn: 0.0408212	total: 2.92s	remaining: 90.2ms
# 970:	learn: 0.0407747	total: 2.92s	remaining: 87.2ms
# 971:	learn: 0.0406753	total: 2.92s	remaining: 84.3ms
# 972:	learn: 0.0406223	total: 2.93s	remaining: 81.3ms
# 973:	learn: 0.0405610	total: 2.93s	remaining: 78.3ms
# 974:	learn: 0.0405019	total: 2.94s	remaining: 75.3ms
# 975:	learn: 0.0404507	total: 2.94s	remaining: 72.3ms
# 976:	learn: 0.0403987	total: 2.94s	remaining: 69.3ms
# 977:	learn: 0.0403628	total: 2.94s	remaining: 66.2ms
# 978:	learn: 0.0402959	total: 2.95s	remaining: 63.2ms
# 979:	learn: 0.0402282	total: 2.95s	remaining: 60.2ms
# 980:	learn: 0.0401492	total: 2.96s	remaining: 57.3ms
# 981:	learn: 0.0400745	total: 2.96s	remaining: 54.3ms
# 982:	learn: 0.0400255	total: 2.96s	remaining: 51.2ms
# 983:	learn: 0.0399622	total: 2.97s	remaining: 48.2ms
# 984:	learn: 0.0399181	total: 2.97s	remaining: 45.2ms
# 985:	learn: 0.0398553	total: 2.97s	remaining: 42.2ms
# 986:	learn: 0.0397895	total: 2.98s	remaining: 39.2ms
# 987:	learn: 0.0397099	total: 2.98s	remaining: 36.2ms
# 988:	learn: 0.0396459	total: 2.98s	remaining: 33.2ms
# 989:	learn: 0.0395880	total: 2.99s	remaining: 30.2ms
# 990:	learn: 0.0395263	total: 2.99s	remaining: 27.2ms
# 991:	learn: 0.0394559	total: 3s	remaining: 24.2ms
# 992:	learn: 0.0393727	total: 3s	remaining: 21.2ms
# 993:	learn: 0.0392982	total: 3s	remaining: 18.1ms
# 994:	learn: 0.0392444	total: 3.01s	remaining: 15.1ms
# 995:	learn: 0.0391886	total: 3.01s	remaining: 12.1ms
# 996:	learn: 0.0390990	total: 3.01s	remaining: 9.06ms
# 997:	learn: 0.0390530	total: 3.02s	remaining: 6.04ms
# 998:	learn: 0.0389649	total: 3.02s	remaining: 3.02ms
# 999:	learn: 0.0389075	total: 3.02s	remaining: 0us

# %%
def conf_mat(cm_list):
    """Function to plot confusion matrix of all classifiers.
    Inputs:
    classifiers: cm_list obtained from the above function eval_metrics
    Ouputs:
    Figure showing confusion matrix of all classifiers.
    """
    fig=plt.figure(figsize=(18,12))
    for i in range(len(cm_list)):
      cm=cm_list[i]
      model=models[i]
      fig.add_subplot(2,3,i+1).set_title(model)
      cm_plot=sns.heatmap(cm,annot=True,cmap='Blues_r')
      cm_plot.set_xlabel('Predcited Values')
      cm_plot.set_ylabel('Actual values')
    return


conf_mat(cm_list)

# %% [markdown]
# Higher the values of true positve rate and false positive rate(left diagonal values) higher will be the accuarcy of the model, hence better the model is.

# %%
# Results_df is the final datafarme which contains model names along with accuarcy and AUC
results_df=pd.DataFrame({'Model':models,'Accuracy':acc_list,'AUC':auc_list})
results_df
# Out:
#                  Model  Accuracy   AUC
# 0  Logistic Regression  0.846154  0.86
# 1                  SVM  0.846154  0.86
# 2          Naive Bayes  0.707692  0.79
# 3        Decision Tree  0.830769  0.87
# 4        Random Forest  0.846154  0.88
# 5             CatBoost  0.892308  0.91

# %%
def finaldf_plot(models,acc_list,auc_list):
    """Function to rearrange the results_df .
    Inputs:
    classifiers: cm_list obtained from the above function eval_metrics
    Ouputs:
    Figure showing confusion matrix of all classifiers.
    """
    df1=pd.DataFrame({'Model':models,'Accuracy':acc_list,'Metric':np.zeros(len(acc_list))})
    df2=pd.DataFrame({'Model':models,'AUC':auc_list,'Metric':np.ones(len(acc_list))})
    f_df=pd.concat([df1,df2])
    f_df['Metric']=f_df['Metric'].map({0:'Accuracy',1:'AUC',})
    return f_df
f_df=finaldf_plot(models,acc_list,auc_list)

#Plot showing the models and their corresponding Accuracy and AUC in descending order.
fig = px.bar(f_df, x="Model", y=["Accuracy",'AUC'], 
                   color="Metric", barmode="group",title="Bar graph showing the accuracy and AUC of the models in ascending order")
fig.update_layout(barmode='group', xaxis={'categoryorder':'total descending'})

fig.show()
# Out:
# <div>                            <div id="7d8c2de6-387d-49dd-ab19-8a5f2b92ab5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d8c2de6-387d-49dd-ab19-8a5f2b92ab5d")) {                    Plotly.newPlot(                        "7d8c2de6-387d-49dd-ab19-8a5f2b92ab5d",                        [{"alignmentgroup":"True","hovertemplate":"Metric=Accuracy<br>Model=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Accuracy","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["Logistic Regression","SVM","Naive Bayes","Decision Tree","Random Forest","CatBoost","Logistic Regression","SVM","Naive Bayes","Decision Tree","Random Forest","CatBoost"],"xaxis":"x","y":[0.8461538461538461,0.8461538461538461,0.7076923076923077,0.8307692307692308,0.8461538461538461,0.8923076923076924,null,null,null,null,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=AUC<br>Model=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"AUC","offsetgroup":"AUC","orientation":"v","showlegend":true,"textposition":"auto","x":["Logistic Regression","SVM","Naive Bayes","Decision Tree","Random Forest","CatBoost","Logistic Regression","SVM","Naive Bayes","Decision Tree","Random Forest","CatBoost"],"xaxis":"x","y":[null,null,null,null,null,null,0.86,0.86,0.79,0.87,0.88,0.91],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# ![newplot%20%281%29.png](attachment:newplot%20%281%29.png)

# %% [markdown]
# # Results
# Ensemble methods such as Catboost and Random forest show highest accuracy and AUC as expected.They work good on small data sets and accurate. Naive Bayes has lower accuarcy becuase it works good for larger datasets.

# %% [markdown]
# ## 6.Hypertuning and SHAPley values
# Hypertuning is done on the best model.i.e CatBoost. The current AUC for CatBoost .89 .

# %%
params = {'iterations':5000,
        'learning_rate':0.01,
        'depth':3,
        'eval_metric':'AUC',
        'verbose':200,
        'od_type':"Iter", # overfit detector
        'od_wait':500, # most recent best iteration to wait before stopping
        'random_seed': 1
          }

cat_model = CatBoostClassifier(**params)
cat_model.fit(X_train, y_train,   
          eval_set=(X_test, y_test), 
          use_best_model=True, # True if we don't want to save trees created after iteration with the best validation score
          plot=True  
         );
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	test: 0.8641582	best: 0.8641582 (0)	total: 1.46ms	remaining: 7.31s
# 200:	test: 0.9528061	best: 0.9540816 (198)	total: 237ms	remaining: 5.65s
# 400:	test: 0.9706633	best: 0.9719388 (396)	total: 457ms	remaining: 5.24s
# 600:	test: 0.9693878	best: 0.9732143 (411)	total: 687ms	remaining: 5.03s
# 800:	test: 0.9655612	best: 0.9732143 (411)	total: 958ms	remaining: 5.02s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.9732142857
# bestIteration = 411
#
# Shrink model to first 412 iterations.

# %% [markdown]
# Hypertuning gives the AUC to .97 which is better comapred without hypertuning.

# %%
from catboost import CatBoostClassifier, Pool
#shap_values = cat_model.get_feature_importance(Pool(X_test, label=y_test,) ,
                                               #type="ShapValues")
shap_values=cat_model.get_feature_importance(Pool(X_train, label=y_train,) ,
                                               type="ShapValues")
expected_value = shap_values[0,-1]
shap_values = shap_values[:,:-1]

# %%
shap.initjs()
shap.force_plot(expected_value, shap_values[0,:], X_test.iloc[0,:])
shap.summary_plot(shap_values, X_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# Each point on the summary plot is a Shapley value for a feature and an instance. The position on the y-axis is determined by the feature and on the x-axis by the Shapley value. The color represents the value of the feature from low(blue) to high(red).
#
# This plot is made of all the dots in the train data. It demonstrates the following information:
#
# Feature importance: Variables are ranked in descending order.
# Impact: The horizontal location shows whether the effect of that value is associated with a higher or lower prediction.
# Original value: Color shows whether that variable is high (in red) or low (in blue) for that observation.
# Correlation: A high value of PPE will have high value on output .i.e person to be classified as Parkinson.

# %%
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %% [markdown]
# The above plot shows the SHAP feature importance measured as the mean absolute Shapley values.
#
# SHAP is based on magnitude of feature attributions. PPE,spread2 and spread1 are the features which contribute to a subject to be classified as Parkinson

# %%
ax = sns.boxplot(x="Parkinson", y="PPE", data=park)

# %% [markdown]
# As concluded from the SHAPley plot, subjects with Parkison disease have higher PPE(a feature of vocal sound) than control group.

# %% [markdown]
# # 7 Conclusion:
# The assignment build six supervised classification models to predict whether a person has Parkinson disease or not. Newly developed algorithm named CatBoost Classifier showed higherst accuracy and AUC comapred with other models.After hypertuning Catboost classifier increased its AUC to .97.

# %% [markdown]
# # Discussion:
# Votingclassifier and other ensembling methods are not performed because CatBoost classifier after hyperparameter tuning gave a good AUC of .97.
